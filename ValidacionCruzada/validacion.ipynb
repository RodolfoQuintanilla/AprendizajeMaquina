# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import KFold

# %%
np.random.seed(200725)

# %%
X = np.array([[10,5,2], [8,3,1], [11,4,4], [10,2,2], [5,2,5], [2,3,4], [1,2,3], [12,5,3], [4,3,2], [1,2,1]])
y = np.array([1,2,1,3,1,2,1,2,3,1])

# %%
# Cross Validation: K-Fold, 4 folds
kf = KFold(n_splits=4)

for train_index, test_index in kf.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
    print("train elementos:", X_train, y_train)
# Out:
# TRAIN: [3 4 5 6 7 8 9] TEST: [0 1 2]
# TRAIN: [0 1 2 6 7 8 9] TEST: [3 4 5]
# TRAIN: [0 1 2 3 4 5 8 9] TEST: [6 7]
# TRAIN: [0 1 2 3 4 5 6 7] TEST: [8 9]

# %%
#Temporal cross validation
